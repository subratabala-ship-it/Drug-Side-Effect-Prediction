# %%
import pandas as pd

reviews_df = pd.read_csv("../data/raw/MedicalReviews_280000.csv")
medicine_df = pd.read_csv("../data/raw/medicine_dataset.csv")
food_df = pd.read_csv("../data/raw/Drug to Food interactions Dataset.csv")
# Out:
# /var/folders/c0/9l4f_q7s7m14pb72fdbyq1q80000gn/T/ipykernel_1868/2057810311.py:4: DtypeWarning: Columns (42,43,44,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   medicine_df = pd.read_csv("../data/raw/medicine_dataset.csv")
